# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import style
style.use("ggplot")

from sklearn.neighbors import KNeighborsClassifier
import os

# %%
df = pd.read_csv("NCAA_data.csv")
df.head()
# Out:
#           player_id            name      class           college  assists  \
# 0   kenyon-martin-1   Kenyon Martin  Above Avg        cincinnati      142
# 1       aj-guyton-1     A.J. Guyton  Below Avg           indiana      403
# 2    jake-voskuhl-1    Jake Voskuhl  Below Avg             uconn      124
# 3  khalid-el-amin-1  Khalid El-Amin       Bust             uconn      479
# 4      mike-smith-1      Mike Smith       Bust  louisiana monroe      147
#
#    blocks  effective_field_goal_percentage  field_goal_percentage  \
# 0     292                            0.587                  0.586
# 1      52                            0.541                  0.455
# 2     193                            0.542                  0.542
# 3      10                            0.486                  0.416
# 4      42                            0.507                  0.428
#
#    free_throw_attempt_rate  free_throw_percentage        ...         \
# 0                    0.494                  0.581        ...
# 1                    0.249                  0.790        ...
# 2                    0.555                  0.656        ...
# 3                    0.257                  0.822        ...
# 4                    0.357                  0.769        ...
#
#    turnovers weight  win_shares_per_40_minutes  assists_per_40  blocks_per_40  \
# 0      139.0  234.0                      0.346        2.781587       5.719882
# 1      218.0  180.0                      0.145        4.944785       0.638037
# 2      160.0  245.0                      0.237        2.271062       3.534799
# 3      188.0  200.0                      0.158        8.915775       0.186133
# 4      241.0  195.0                      0.165        3.034056       0.866873
#
#    points_per_40  steals_per_40  three_pointers_per_40  total_rebounds_per_40  \
# 0      25.053869       2.428991               0.039177              17.022527
# 1      25.766871       1.582822               3.472393               5.263804
# 2      15.805861       1.575092               0.000000              16.117216
# 3      30.711959       3.462075               3.629595               5.937645
# 4      21.919505       1.857585               2.683179               9.267286
#
#    turnovers_per_40
# 0          2.722821
# 1          2.674847
# 2          2.930403
# 3          3.499302
# 4          4.974200
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (853, 30)

# %%
df.dtypes
# Out:
# player_id                           object
# name                                object
# class                               object
# college                             object
# assists                              int64
# blocks                               int64
# effective_field_goal_percentage    float64
# field_goal_percentage              float64
# free_throw_attempt_rate            float64
# free_throw_percentage              float64
# games_played                         int64
# height                              object
# minutes_played                     float64
# points                               int64
# steals                               int64
# three_point_percentage             float64
# three_pointers                     float64
# total_rebounds                       int64
# true_shooting_percentage           float64
# turnover_percentage                float64
# turnovers                          float64
# weight                             float64
# win_shares_per_40_minutes          float64
# assists_per_40                     float64
# blocks_per_40                      float64
# points_per_40                      float64
# steals_per_40                      float64
# three_pointers_per_40              float64
# total_rebounds_per_40              float64
# turnovers_per_40                   float64
# dtype: object

# %%
X = ["steals_per_40","total_rebounds_per_40  "]

# %%
y = df["class"]
target_names = ["All_Star","Above_Average","Average","Below_Average","Bust"]

# %%
data = df.drop("class", axis =1)
feature_names = data.columns
data.head()
# Out:
#           player_id            name           college  assists  blocks  \
# 0   kenyon-martin-1   Kenyon Martin        cincinnati      142     292
# 1       aj-guyton-1     A.J. Guyton           indiana      403      52
# 2    jake-voskuhl-1    Jake Voskuhl             uconn      124     193
# 3  khalid-el-amin-1  Khalid El-Amin             uconn      479      10
# 4      mike-smith-1      Mike Smith  louisiana monroe      147      42
#
#    effective_field_goal_percentage  field_goal_percentage  \
# 0                            0.587                  0.586
# 1                            0.541                  0.455
# 2                            0.542                  0.542
# 3                            0.486                  0.416
# 4                            0.507                  0.428
#
#    free_throw_attempt_rate  free_throw_percentage  games_played  \
# 0                    0.494                  0.581           116
# 1                    0.249                  0.790           128
# 2                    0.555                  0.656           138
# 3                    0.257                  0.822           108
# 4                    0.357                  0.769            55
#
#          ...        turnovers  weight  win_shares_per_40_minutes  \
# 0        ...            139.0   234.0                      0.346
# 1        ...            218.0   180.0                      0.145
# 2        ...            160.0   245.0                      0.237
# 3        ...            188.0   200.0                      0.158
# 4        ...            241.0   195.0                      0.165
#
#    assists_per_40  blocks_per_40  points_per_40  steals_per_40  \
# 0        2.781587       5.719882      25.053869       2.428991
# 1        4.944785       0.638037      25.766871       1.582822
# 2        2.271062       3.534799      15.805861       1.575092
# 3        8.915775       0.186133      30.711959       3.462075
# 4        3.034056       0.866873      21.919505       1.857585
#
#    three_pointers_per_40  total_rebounds_per_40  turnovers_per_40
# 0               0.039177              17.022527          2.722821
# 1               3.472393               5.263804          2.674847
# 2               0.000000              16.117216          2.930403
# 3               3.629595               5.937645          3.499302
# 4               2.683179               9.267286          4.974200
#
# [5 rows x 29 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(data,target, random_state =42)

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-c745450c0c46> in <module>
#       2 from sklearn.svm import SVC
#       3 model = SVC(kernel='linear')
# ----> 4 model.fit(X, y)
#
# ~\.conda\envs\PythonData\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     144         X, y = check_X_y(X, y, dtype=np.float64,
#     145                          order='C', accept_sparse='csr',
# --> 146                          accept_large_sparse=False)
#     147         y = self._validate_targets(y)
#     148
#
# ~\.conda\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\.conda\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# ~\.conda\envs\PythonData\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# ValueError: could not convert string to float: 'steals_per_40'
