# %%
# Set the seed value for the notebook so the results are reproducible

from numpy.random import seed
seed(1)

# %%
# import necessary libraries

import warnings
warnings.simplefilter('ignore')

import numpy as np

import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import make_classification

# %%
# load pandas DataFrame
ncaaDF = pd.read_csv("NCAA_data.csv")
ncaaDF.head()
# Out:
#           player_id            name      class           college  assists  \
# 0   kenyon-martin-1   Kenyon Martin  Above Avg        cincinnati      142
# 1       aj-guyton-1     A.J. Guyton  Below Avg           indiana      403
# 2    jake-voskuhl-1    Jake Voskuhl  Below Avg             uconn      124
# 3  khalid-el-amin-1  Khalid El-Amin       Bust             uconn      479
# 4      mike-smith-1      Mike Smith       Bust  louisiana monroe      147
#
#    blocks  effective_field_goal_percentage  field_goal_percentage  \
# 0     292                            0.587                  0.586
# 1      52                            0.541                  0.455
# 2     193                            0.542                  0.542
# 3      10                            0.486                  0.416
# 4      42                            0.507                  0.428
#
#    free_throw_attempt_rate  free_throw_percentage  ...  turnover_percentage  \
# 0                    0.494                  0.581  ...                 14.3
# 1                    0.249                  0.790  ...                 13.6
# 2                    0.555                  0.656  ...                 23.0
# 3                    0.257                  0.822  ...                 15.6
# 4                    0.357                  0.769  ...                 20.0
#
#    turnovers  win_shares_per_40_minutes  assists_per_40  blocks_per_40  \
# 0      139.0                      0.346        2.781587       5.719882
# 1      218.0                      0.145        4.944785       0.638037
# 2      160.0                      0.237        2.271062       3.534799
# 3      188.0                      0.158        8.915775       0.186133
# 4      241.0                      0.165        3.034056       0.866873
#
#    points_per_40  steals_per_40  three_pointers_per_40  total_rebounds_per_40  \
# 0      25.053869       2.428991               0.039177              17.022527
# 1      25.766871       1.582822               3.472393               5.263804
# 2      15.805861       1.575092               0.000000              16.117216
# 3      30.711959       3.462075               3.629595               5.937645
# 4      21.919505       1.857585               2.683179               9.267286
#
#    turnovers_per_40
# 0          2.722821
# 1          2.674847
# 2          2.930403
# 3          3.499302
# 4          4.974200
#
# [5 rows x 29 columns]

# %%
nbaDF.dtypes
# Out:
# player_id                           object
# name                                object
# class                               object
# college                             object
# assists                              int64
# blocks                               int64
# effective_field_goal_percentage    float64
# field_goal_percentage              float64
# free_throw_attempt_rate            float64
# free_throw_percentage              float64
# games_played                         int64
# height                               int64
# minutes_played                     float64
# points                               int64
# steals                               int64
# three_point_percentage             float64
# three_pointers                     float64
# total_rebounds                       int64
# true_shooting_percentage           float64
# turnover_percentage                float64
# turnovers                          float64
# win_shares_per_40_minutes          float64
# assists_per_40                     float64
# blocks_per_40                      float64
# points_per_40                      float64
# steals_per_40                      float64
# three_pointers_per_40              float64
# total_rebounds_per_40              float64
# turnovers_per_40                   float64
# dtype: object

# %%
# Split the x variables (WITHOUT Player, Team, and College Columns) from the y variable

X = ncaaDF.drop(["class","player_id","name","college"], axis=1)
y = ncaaDF["class"]
print(f"Number of Rows and Independent(X) Variable: {X.shape}, \n Number of Rows (One Dependent(Y) variable): {y.shape}")
# Out:
# Number of Rows and Independent(X) Variable: (853, 25),
#  Number of Rows (One Dependent(Y) variable): (853,)

# %%
# Label encoding for Dependent(Y) Variable

label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

for label, original_class in zip(encoded_y, y):
    print('Original Class: ' + str(original_class))
    print('Encoded Label: ' + str(label))
    print('-' * 12)
# Out:
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Bust
# Encoded Label: 2
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Star
# Encoded Label: 3
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Above Avg
# Encoded Label: 0
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------
# Original Class: Below Avg
# Encoded Label: 1
# ------------

# %%
# Use train_test_split to create training and testing data

X_train, X_test, y_train, y_test = train_test_split(X, encoded_y, test_size=float(0.2), random_state=1)

# %%
X_scaler = StandardScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Make sure the dependent variable categories are set up

# y_train_categorical = to_categorical(y_train)
# y_test_categorical = to_categorical(y_test)

# %%
# Create a normal neural network with 12 inputs (12 independent variables), 6 hidden nodes, and 4 outputs
# input_dim refers to number of independent(X) variables
# units is output shape i.e. number of categories in the Dependent Variable Column
# In this example, final units=4 because Four Rankings: Star, Above Average, Below Average, Bust

model = Sequential()
model.add(Dense(units=6, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(units=6, activation='relu'))
model.add(Dense(units=len(y.unique()), activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 6)                 156
# _________________________________________________________________
# dense_16 (Dense)             (None, 6)                 42
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 28
# =================================================================
# Total params: 226
# Trainable params: 226
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit the model

model.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    batch_size=10,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
#  - 0s - loss: 1.6473 - acc: 0.2639
# Epoch 2/100
#  - 0s - loss: 1.5069 - acc: 0.2874
# Epoch 3/100
#  - 0s - loss: 1.4271 - acc: 0.3226
# Epoch 4/100
#  - 0s - loss: 1.3822 - acc: 0.3255
# Epoch 5/100
#  - 0s - loss: 1.3560 - acc: 0.3416
# Epoch 6/100
#  - 0s - loss: 1.3368 - acc: 0.3607
# Epoch 7/100
#  - 0s - loss: 1.3233 - acc: 0.3695
# Epoch 8/100
#  - 0s - loss: 1.3124 - acc: 0.3812
# Epoch 9/100
#  - 0s - loss: 1.3031 - acc: 0.3871
# Epoch 10/100
#  - 0s - loss: 1.2956 - acc: 0.3871
# Epoch 11/100
#  - 0s - loss: 1.2893 - acc: 0.3900
# Epoch 12/100
#  - 0s - loss: 1.2837 - acc: 0.3930
# Epoch 13/100
#  - 0s - loss: 1.2791 - acc: 0.4047
# Epoch 14/100
#  - 0s - loss: 1.2749 - acc: 0.4047
# Epoch 15/100
#  - 0s - loss: 1.2721 - acc: 0.3974
# Epoch 16/100
#  - 0s - loss: 1.2685 - acc: 0.4062
# Epoch 17/100
#  - 0s - loss: 1.2659 - acc: 0.4091
# Epoch 18/100
#  - 0s - loss: 1.2618 - acc: 0.4120
# Epoch 19/100
#  - 0s - loss: 1.2585 - acc: 0.4091
# Epoch 20/100
#  - 0s - loss: 1.2558 - acc: 0.4003
# Epoch 21/100
#  - 0s - loss: 1.2525 - acc: 0.4076
# Epoch 22/100
#  - 0s - loss: 1.2496 - acc: 0.4120
# Epoch 23/100
#  - 0s - loss: 1.2474 - acc: 0.4106
# Epoch 24/100
#  - 0s - loss: 1.2441 - acc: 0.4150
# Epoch 25/100
#  - 0s - loss: 1.2416 - acc: 0.4179
# Epoch 26/100
#  - 0s - loss: 1.2383 - acc: 0.4223
# Epoch 27/100
#  - 0s - loss: 1.2357 - acc: 0.4194
# Epoch 28/100
#  - 0s - loss: 1.2325 - acc: 0.4194
# Epoch 29/100
#  - 0s - loss: 1.2303 - acc: 0.4238
# Epoch 30/100
#  - 0s - loss: 1.2274 - acc: 0.4194
# Epoch 31/100
#  - 0s - loss: 1.2241 - acc: 0.4194
# Epoch 32/100
#  - 0s - loss: 1.2215 - acc: 0.4164
# Epoch 33/100
#  - 0s - loss: 1.2189 - acc: 0.4223
# Epoch 34/100
#  - 0s - loss: 1.2160 - acc: 0.4223
# Epoch 35/100
#  - 0s - loss: 1.2137 - acc: 0.4223
# Epoch 36/100
#  - 0s - loss: 1.2118 - acc: 0.4252
# Epoch 37/100
#  - 0s - loss: 1.2096 - acc: 0.4194
# Epoch 38/100
#  - 0s - loss: 1.2081 - acc: 0.4238
# Epoch 39/100
#  - 0s - loss: 1.2057 - acc: 0.4267
# Epoch 40/100
#  - 0s - loss: 1.2029 - acc: 0.4252
# Epoch 41/100
#  - 0s - loss: 1.2012 - acc: 0.4282
# Epoch 42/100
#  - 0s - loss: 1.1995 - acc: 0.4267
# Epoch 43/100
#  - 0s - loss: 1.1975 - acc: 0.4296
# Epoch 44/100
#  - 0s - loss: 1.1954 - acc: 0.4355
# Epoch 45/100
#  - 0s - loss: 1.1938 - acc: 0.4311
# Epoch 46/100
#  - 0s - loss: 1.1922 - acc: 0.4326
# Epoch 47/100
#  - 0s - loss: 1.1905 - acc: 0.4355
# Epoch 48/100
#  - 0s - loss: 1.1895 - acc: 0.4326
# Epoch 49/100
#  - 0s - loss: 1.1868 - acc: 0.4413
# Epoch 50/100
#  - 0s - loss: 1.1853 - acc: 0.4399
# Epoch 51/100
#  - 0s - loss: 1.1843 - acc: 0.4428
# Epoch 52/100
#  - 0s - loss: 1.1820 - acc: 0.4487
# Epoch 53/100
#  - 0s - loss: 1.1804 - acc: 0.4487
# Epoch 54/100
#  - 0s - loss: 1.1789 - acc: 0.4413
# Epoch 55/100
#  - 0s - loss: 1.1770 - acc: 0.4457
# Epoch 56/100
#  - 0s - loss: 1.1756 - acc: 0.4516
# Epoch 57/100
#  - 0s - loss: 1.1735 - acc: 0.4487
# Epoch 58/100
#  - 0s - loss: 1.1730 - acc: 0.4575
# Epoch 59/100
#  - 0s - loss: 1.1712 - acc: 0.4531
# Epoch 60/100
#  - 0s - loss: 1.1699 - acc: 0.4633
# Epoch 61/100
#  - 0s - loss: 1.1679 - acc: 0.4589
# Epoch 62/100
#  - 0s - loss: 1.1671 - acc: 0.4575
# Epoch 63/100
#  - 0s - loss: 1.1650 - acc: 0.4619
# Epoch 64/100
#  - 0s - loss: 1.1642 - acc: 0.4619
# Epoch 65/100
#  - 0s - loss: 1.1619 - acc: 0.4619
# Epoch 66/100
#  - 0s - loss: 1.1625 - acc: 0.4619
# Epoch 67/100
#  - 0s - loss: 1.1608 - acc: 0.4648
# Epoch 68/100
#  - 0s - loss: 1.1588 - acc: 0.4619
# Epoch 69/100
#  - 0s - loss: 1.1580 - acc: 0.4663
# Epoch 70/100
#  - 0s - loss: 1.1567 - acc: 0.4619
# Epoch 71/100
#  - 0s - loss: 1.1557 - acc: 0.4677
# Epoch 72/100
#  - 0s - loss: 1.1544 - acc: 0.4619
# Epoch 73/100
#  - 0s - loss: 1.1529 - acc: 0.4648
# Epoch 74/100
#  - 0s - loss: 1.1525 - acc: 0.4589
# Epoch 75/100
#  - 0s - loss: 1.1519 - acc: 0.4677
# Epoch 76/100
#  - 0s - loss: 1.1506 - acc: 0.4677
# Epoch 77/100
#  - 0s - loss: 1.1518 - acc: 0.4604
# Epoch 78/100
#  - 0s - loss: 1.1482 - acc: 0.4677
# Epoch 79/100
#  - 0s - loss: 1.1484 - acc: 0.4619
# Epoch 80/100
#  - 0s - loss: 1.1467 - acc: 0.4663
# Epoch 81/100
#  - 0s - loss: 1.1453 - acc: 0.4633
# Epoch 82/100
#  - 0s - loss: 1.1441 - acc: 0.4604
# Epoch 83/100
#  - 0s - loss: 1.1437 - acc: 0.4604
# Epoch 84/100
#  - 0s - loss: 1.1431 - acc: 0.4633
# Epoch 85/100
#  - 0s - loss: 1.1420 - acc: 0.4575
# Epoch 86/100
#  - 0s - loss: 1.1416 - acc: 0.4677
# Epoch 87/100
#  - 0s - loss: 1.1399 - acc: 0.4721
# Epoch 88/100
#  - 0s - loss: 1.1390 - acc: 0.4619
# Epoch 89/100
#  - 0s - loss: 1.1384 - acc: 0.4707
# Epoch 90/100
#  - 0s - loss: 1.1377 - acc: 0.4736
# Epoch 91/100
#  - 0s - loss: 1.1366 - acc: 0.4765
# Epoch 92/100
#  - 0s - loss: 1.1351 - acc: 0.4765
# Epoch 93/100
#  - 0s - loss: 1.1356 - acc: 0.4765
# Epoch 94/100
#  - 0s - loss: 1.1343 - acc: 0.4707
# Epoch 95/100
#  - 0s - loss: 1.1348 - acc: 0.4751
# Epoch 96/100
#  - 0s - loss: 1.1328 - acc: 0.4780
# Epoch 97/100
#  - 0s - loss: 1.1319 - acc: 0.4736
# Epoch 98/100
#  - 0s - loss: 1.1311 - acc: 0.4692
# Epoch 99/100
#  - 0s - loss: 1.1306 - acc: 0.4780
# Epoch 100/100
#  - 0s - loss: 1.1318 - acc: 0.4736

# %%
# Save the model

model.save("Draft_Machine_Model.h5")

# %%
# Evaluate the model using the testing data

model = load_model("Draft_Machine_Model.h5")
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
#  - 0s - loss: 1.2887 - acc: 0.3684
# Loss: 1.28871070223245, Accuracy: 0.3684210479259491
