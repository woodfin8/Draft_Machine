# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("NBA_data.csv")
df.head()
# Out:
#    Win Shares  Mins Played (per game)          Player  Games  Year  Rank  \
# 0        48.0                    30.6   Kenyon Martin  757.0  2000     1
# 1        11.6                    14.3    Jake Voskuhl  450.0  2000    33
# 2         0.6                    18.7  Khalid El-Amin   50.0  2000    34
# 3        -0.1                    10.6      Mike Smith   17.0  2000    35
# 4        20.0                    17.3     Eddie House  717.0  2000    37
#
#    Points(per game)  WS/48  Box +/-  Value Overall Replacement Player Team  \
# 0              12.3  0.100      0.7                              15.5  NJN
# 1               4.0  0.087     -2.2                              -0.3  CHI
# 2               6.3  0.030     -3.8                              -0.4  CHI
# 3               3.0 -0.033     -5.5                              -0.2  WAS
# 4               7.5  0.077     -1.5                               1.6  MIA
#
#                              College  Years  Mins Played (Total)  \
# ...

# %%
target = df["Win Shares"]
target_names = ["negative", "positive"]

# %%
win = df.drop("Win Shares", axis=1)
feature_names = win.columns
win.head()
# Out:
#    Mins Played (per game)          Player  Games  Year  Rank  \
# 0                    30.6   Kenyon Martin  757.0  2000     1
# 1                    14.3    Jake Voskuhl  450.0  2000    33
# 2                    18.7  Khalid El-Amin   50.0  2000    34
# 3                    10.6      Mike Smith   17.0  2000    35
# 4                    17.3     Eddie House  717.0  2000    37
#
#    Points(per game)  WS/48  Box +/-  Value Overall Replacement Player Team  \
# 0              12.3  0.100      0.7                              15.5  NJN
# 1               4.0  0.087     -2.2                              -0.3  CHI
# 2               6.3  0.030     -3.8                              -0.4  CHI
# 3               3.0 -0.033     -5.5                              -0.2  WAS
# 4               7.5  0.077     -1.5                               1.6  MIA
#
#                              College  Years  Mins Played (Total)  \
# 0                         Cincinnati   15.0              23134.0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(win, target, random_state=42)

# %%
# Support vector machine linear classifier

#LABEL ENCODING BLOCK

X_train = X_train.apply(LabelEncoder().fit_transform) 
win = win.drop(X_train.columns, axis=1)
# #END LABEL ENCODING BLOCK


from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0e9505136cda> in <module>
#      10 from sklearn.svm import SVC
#      11 model = SVC(kernel='linear')
# ---> 12 model.fit(X_train, y_train)
#
# ~\.conda\envs\pythondata\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     146         X, y = check_X_y(X, y, dtype=np.float64,
#     147                          order='C', accept_sparse='csr',
# --> 148                          accept_large_sparse=False)
#     149         y = self._validate_targets(y)
#     150
#
# ~\.conda\envs\pythondata\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     759     else:
# ...
