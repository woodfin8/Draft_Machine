# %%
import pandas as pd
import os

# %%
df = pd.read_csv("C:/Learn/Draft_Machine/nba_data/2018.csv")

files = [file for file in os.listdir('./Nba_Data')]

all_year_data = pd.DataFrame()

for file in files:
    df = pd.read_csv("Nba_Data/" + file)
    all_year_data = pd.concat([all_year_data, df])
    
all_year_data.head(100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':
#    Advanced Per Game              Round 1 Shooting Totals Unnamed: 0  \
# 0        WS       MP               Player      FG%      G         Rk
# 1        48     30.6        Kenyon Martin    0.483    757          1
# 2      21.3     19.8       Stromile Swift    0.473    547          2
# 3       9.5     26.3         Darius Miles    0.472    446          3
# 4       2.7     20.9         Marcus Fizer    0.435    289          4
# 5      60.7     26.9          Mike Miller    0.459   1032          5
# 6       6.4     17.2      DerMarr Johnson    0.411    344          6
# ...
